# %%
# import required libraries

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# for scaling
from sklearn.preprocessing import minmax_scale

# %%
# set seed for reproducibility
np.random.seed(0)

# %%
# read in the csv dataset
df = pd.read_csv('beyonce_tracks.csv')

# %%
# check that the file has been read in, by looking at the 1st few rows

df.head()
# Out:
#      artist_name           track_name   album_name  is_explicit    genres  \
# 0        Beyoncé        I'M THAT GIRL  RENAISSANCE         True  pop, r&b
# 1        Beyoncé                 COZY  RENAISSANCE         True  pop, r&b
# 2        Beyoncé      ALIEN SUPERSTAR  RENAISSANCE         True  pop, r&b
# 3        Beyoncé              CUFF IT  RENAISSANCE         True  pop, r&b
# 4  Beyoncé, BEAM  ENERGY (feat. Beam)  RENAISSANCE        False  pop, r&b
#
#   release_date                track_id  danceability  valence  energy  \
# 0   2022-07-29  1MpCaOeUWhox2Fgigbe1cL         0.554    0.136   0.535
# 1   2022-07-29  0mKGwFMHzTprtS2vpR3b6s         0.556    0.367   0.630
# 2   2022-07-29  1Hohk6AufHZOrrhMXZppax         0.545    0.464   0.641
# 3   2022-07-29  1xzi1Jcr7mEi9K2RfzLOqS         0.780    0.642   0.689
# 4   2022-07-29  0314PeD1sQNonfVWix3B2K         0.903    0.587   0.519
#
#    loudness  acousticness  instrumentalness  liveness  speechiness  key  \
# 0    -8.959      0.061600          0.000013    0.1240       0.1860    5
# 1    -8.150      0.000828          0.004680    0.1550       0.1020    7
# 2    -6.398      0.004530          0.000066    0.1710       0.0998   10
# 3    -5.668      0.036800          0.000010    0.0698       0.1410    7
# 4    -9.151      0.281000          0.000106    0.1550       0.2600    1
#
#      tempo  mode  duration_ms  time_signature
# 0  105.865     0       208014               4
# 1  149.147     1       210372               5
# 2  121.892     0       215460               4
# 3  115.042     1       225389               4
# 4  114.991     1       116727               4

# %%
# check hte shape of the dataset
df.shape
# Out:
# (336, 20)

# %%
# check the datatypes we are dealing with
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       336 non-null    object
#  1   track_name        336 non-null    object
#  2   album_name        336 non-null    object
#  3   is_explicit       336 non-null    bool
#  4   genres            336 non-null    object
#  5   release_date      336 non-null    object
#  6   track_id          336 non-null    object
#  7   danceability      336 non-null    float64
#  8   valence           336 non-null    float64
#  9   energy            336 non-null    float64
#  10  loudness          336 non-null    float64
#  11  acousticness      336 non-null    float64
#  12  instrumentalness  336 non-null    float64
#  13  liveness          336 non-null    float64
#  14  speechiness       336 non-null    float64
#  15  key               336 non-null    int64
#  16  tempo             336 non-null    float64
#  17  mode              336 non-null    int64
#  18  duration_ms       336 non-null    int64
#  19  time_signature    336 non-null    int64
# dtypes: bool(1), float64(9), int64(4), object(6)
# memory usage: 50.3+ KB

# %%
# check the data stats
df.describe()
# Out:
#        danceability     valence      energy    loudness  acousticness  \
# count    336.000000  336.000000  336.000000  336.000000    336.000000
# mean       0.612640    0.490362    0.682492   -7.289720      0.138767
# std        0.155603    0.233648    0.189090    2.854806      0.219504
# min        0.143000    0.038800    0.045200  -27.432000      0.000066
# 25%        0.508750    0.323000    0.557750   -8.451000      0.005295
# 50%        0.635000    0.489500    0.715000   -6.750500      0.037200
# 75%        0.725250    0.651000    0.821750   -5.446750      0.158000
# max        0.925000    0.971000    0.993000   -2.706000      0.994000
#
#        instrumentalness    liveness  speechiness         key       tempo  \
# count        336.000000  336.000000   336.000000  336.000000  336.000000
# mean           0.079687    0.305424     0.168143    5.181548  121.615961
# std            0.209146    0.265685     0.150844    3.568488   29.594229
# min            0.000000    0.016200     0.027100    0.000000   66.930000
# 25%            0.000000    0.097200     0.053650    1.000000   97.076500
# 50%            0.000020    0.201000     0.106500    6.000000  123.015000
# 75%            0.005510    0.392750     0.254750    8.000000  136.039000
# max            0.937000    0.983000     0.940000   11.000000  216.788000
#
#              mode    duration_ms  time_signature
# count  336.000000     336.000000      336.000000
# mean     0.651786  250289.229167        3.922619
# std      0.477115   98478.940431        0.408814
# min      0.000000   16373.000000        1.000000
# 25%      0.000000  200813.000000        4.000000
# 50%      1.000000  228933.000000        4.000000
# 75%      1.000000  278884.750000        4.000000
# max      1.000000  597520.000000        5.000000

# %%
# drop columns that seem irrelevant to our analysis
df.drop(['track_id'],  axis=1, inplace=True)

# %%
# check that relvant column was dropped
df.shape
# Out:
# (336, 19)

# %%
df.columns
# Out:
# Index(['artist_name', 'track_name', 'album_name', 'is_explicit', 'genres',
#        'release_date', 'danceability', 'valence', 'energy', 'loudness',
#        'acousticness', 'instrumentalness', 'liveness', 'speechiness', 'key',
#        'tempo', 'mode', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# Check if there or columns with missing data

df.isnull()
# Out:
#      artist_name  track_name  album_name  is_explicit  genres  release_date  \
# 0          False       False       False        False   False         False
# 1          False       False       False        False   False         False
# 2          False       False       False        False   False         False
# 3          False       False       False        False   False         False
# 4          False       False       False        False   False         False
# ..           ...         ...         ...          ...     ...           ...
# 331        False       False       False        False   False         False
# 332        False       False       False        False   False         False
# 333        False       False       False        False   False         False
# 334        False       False       False        False   False         False
# 335        False       False       False        False   False         False
#
#      danceability  valence  energy  loudness  acousticness  instrumentalness  \
# 0           False    False   False     False         False             False
# 1           False    False   False     False         False             False
# 2           False    False   False     False         False             False
# 3           False    False   False     False         False             False
# 4           False    False   False     False         False             False
# ..            ...      ...     ...       ...           ...               ...
# 331         False    False   False     False         False             False
# 332         False    False   False     False         False             False
# 333         False    False   False     False         False             False
# 334         False    False   False     False         False             False
# 335         False    False   False     False         False             False
#
#      liveness  speechiness    key  tempo   mode  duration_ms  time_signature
# 0       False        False  False  False  False        False           False
# 1       False        False  False  False  False        False           False
# 2       False        False  False  False  False        False           False
# 3       False        False  False  False  False        False           False
# 4       False        False  False  False  False        False           False
# ..        ...          ...    ...    ...    ...          ...             ...
# 331     False        False  False  False  False        False           False
# 332     False        False  False  False  False        False           False
# 333     False        False  False  False  False        False           False
# 334     False        False  False  False  False        False           False
# 335     False        False  False  False  False        False           False
#
# [336 rows x 19 columns]

# %%
# since i don't have clarity of whthere there's null values between index 4 - 331, lets use another method
# This method will give a breakdown of columns, and number of missing values in each column
df.isna().sum()
# Out:
# artist_name         0
# track_name          0
# album_name          0
# is_explicit         0
# genres              0
# release_date        0
# danceability        0
# valence             0
# energy              0
# loudness            0
# acousticness        0
# instrumentalness    0
# liveness            0
# speechiness         0
# key                 0
# tempo               0
# mode                0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
# identify/ locate any duplicate data within our dataset
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [artist_name, track_name, album_name, is_explicit, genres, release_date, danceability, valence, energy, loudness, acousticness, instrumentalness, liveness, speechiness, key, tempo, mode, duration_ms, time_signature]
# Index: []

# %%
# remove trailing white spaces from our 19 colums
# could we use a function to do the same for all 19 columns?

df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df.head()
# Out:
#      artist_name           track_name   album_name  is_explicit    genres  \
# 0        Beyoncé        I'M THAT GIRL  RENAISSANCE         True  pop, r&b
# 1        Beyoncé                 COZY  RENAISSANCE         True  pop, r&b
# 2        Beyoncé      ALIEN SUPERSTAR  RENAISSANCE         True  pop, r&b
# 3        Beyoncé              CUFF IT  RENAISSANCE         True  pop, r&b
# 4  Beyoncé, BEAM  ENERGY (feat. Beam)  RENAISSANCE        False  pop, r&b
#
#   release_date  danceability  valence  energy  loudness  acousticness  \
# 0   2022-07-29         0.554    0.136   0.535    -8.959      0.061600
# 1   2022-07-29         0.556    0.367   0.630    -8.150      0.000828
# 2   2022-07-29         0.545    0.464   0.641    -6.398      0.004530
# 3   2022-07-29         0.780    0.642   0.689    -5.668      0.036800
# 4   2022-07-29         0.903    0.587   0.519    -9.151      0.281000
#
#    instrumentalness  liveness  speechiness  key    tempo  mode  duration_ms  \
# 0          0.000013    0.1240       0.1860    5  105.865     0       208014
# 1          0.004680    0.1550       0.1020    7  149.147     1       210372
# 2          0.000066    0.1710       0.0998   10  121.892     0       215460
# 3          0.000010    0.0698       0.1410    7  115.042     1       225389
# 4          0.000106    0.1550       0.2600    1  114.991     1       116727
#
#    time_signature
# 0               4
# 1               5
# 2               4
# 3               4
# 4               4

# %%
# Let's check if we're the dates are formatted consistently in the release_date column
df.release_date.dtype
# Out:
# dtype('O')

# %%
# We see that the format of release dates is object instead of date formatt - so we will parse the date
# Create a new column for parsed dates
df['release_date_parsed'] = pd.to_datetime(df['release_date'], format="%Y-%m-%d")

# %%
# check that the date parsed column is in the expected format
df['release_date_parsed'].head()
# Out:
# 0   2022-07-29
# 1   2022-07-29
# 2   2022-07-29
# 3   2022-07-29
# 4   2022-07-29
# Name: release_date_parsed, dtype: datetime64[ns]

# %%
df.shape
# Out:
# (336, 21)

# %%
df['release_date_parsed'].sort_values().head()
# Out:
# 335   2002-06-17
# 333   2002-06-17
# 332   2002-06-17
# 334   2002-06-17
# 331   2003-05-20
# Name: release_date_parsed, dtype: datetime64[ns]

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# Number of duplicate rows: 0

# %%
# Find duplicate track names
duplicate_tracks = df['track_name'].duplicated(keep=False)
print(f"Number of matching track names: {duplicate_tracks.sum()}")
# Out:
# Number of matching track names: 84

# %%
# Display duplicate track names
if duplicate_tracks.sum() > 0:
    duplicated_tracks_df = df[duplicate_tracks].sort_values(by='track_name')
    print(duplicated_tracks_df[['artist_name', 'track_name', 'album_name', 'release_date']])
# Out:
#                            artist_name               track_name  \
# 30   Beyoncé, Shatta Wale, Major Lazer                  ALREADY
# 20   Beyoncé, Shatta Wale, Major Lazer                  ALREADY
# 272       Beyoncé, Alejandro Fernández              Amor Gitano
# 185       Beyoncé, Alejandro Fernández              Amor Gitano
# 16                             Beyoncé                   BIGGER
# ..                                 ...                      ...
# 194                            Beyoncé                Suga Mama
# 242                            Beyoncé             Sweet Dreams
# 164                            Beyoncé             Sweet Dreams
# 174                     Beyoncé, JAY-Z  Upgrade U (feat. Jay-Z)
# 195                     Beyoncé, JAY-Z  Upgrade U (feat. Jay-Z)
#
#                                    album_name release_date
# 30                    The Lion King: The Gift   2019-07-19
# 20   The Lion King: The Gift [Deluxe Edition]   2020-07-31
# 272                            Irreemplazable   2007-08-27
# 185                      B'Day Deluxe Edition   2007-05-29
# 16   The Lion King: The Gift [Deluxe Edition]   2020-07-31
# ..                                        ...          ...
# 194                                     B'Day   2006-09-04
# 242    Ego/Sweet Dreams Singles & Dance Mixes   2009-07-21
# 164                       I AM...SASHA FIERCE   2008-11-14
# 174                      B'Day Deluxe Edition   2007-05-29
# 195                                     B'Day   2006-09-04
#
# [84 rows x 4 columns]

# %%
# I want to delete the duplicate track names
df.drop_duplicates(subset='track_name', keep='first', inplace=True)

# %%
df.shape
# Out:
# (290, 21)

# %%
# Let's compare danceability vs average release years
# The release year can appear multiple times.
# This could be due to more than 1 album or song being release in that year.
# What we will do for better visualisation is to aggregate the danceability 

# Group by release year and calculate the mean danceability for each year
avg_danceability = df.groupby(df['release_date_parsed'].dt.year)['danceability'].mean()

# Plot the average danceability by release year
ax = avg_danceability.plot(kind='bar', title='Average Danceability by Release Year')
ax.set_xlabel('Release Year')
ax.set_ylabel('Average Danceability')

# Rotate x-axis labels
plt.xticks(rotation=45)

plt.show()

# %%
# Note 2022 peak
# Let's identify which  tracks/album/ this was

# Lets extract the 2022 danceability data
most_danceable_tracks_2022 = df[df['release_date_parsed'].dt.year == 2022]['track_name']

# Print the name of the most explicit 2019 album
most_danceable_albums_2022 = df[df['release_date_parsed'].dt.year == 2022]['album_name'].value_counts()
print(most_danceable_albums_2022)
# Out:
# album_name
# RENAISSANCE              16
# BREAK MY SOUL REMIXES     4
# Name: count, dtype: int64

# %%
df['genres'].dtype
# Out:
# dtype('O')

# %%
# Let's consider the most the explicity over the years

# Group by release year and count the occurrences of explicit tracks
explicit_counts = df.groupby(df['release_date_parsed'].dt.year)['is_explicit'].sum() # True =1 False = 0

# Group by release year and calculate the mean danceability for each year
avg_danceability = df.groupby(df['release_date_parsed'].dt.year)['danceability'].mean()

# Plot the count of explicit tracks by release year
ax = explicit_counts.plot(kind='bar', title='Number of Explicit Tracks Over the Years')
ax.set_xlabel('Release Year')
ax.set_ylabel('Number of Explicit Tracks')

# Rotate x-axis labels
plt.xticks(rotation=45)

plt.show()

# %%
# Lets extract the 2014 explicit tracks data
explicit_tracks_2014 = df[df['release_date_parsed'].dt.year == 2014]['track_name']

# Print the name of the most explicit 2014 album
explicit_albums_2014 = df[df['release_date_parsed'].dt.year == 2014]['album_name'].value_counts()
print(explicit_albums_2014)
# Out:
# album_name
# BEYONCÉ [Platinum Edition]    20
# Name: count, dtype: int64

# %%
# Lets extract the 2019 explicit tracks data
explicit_tracks_2019 = df[df['release_date_parsed'].dt.year == 2019]['track_name']

# Print the name of the most explicit 2019 album
explicit_albums_2019 = df[df['release_date_parsed'].dt.year == 2019]['album_name'].value_counts()
print(explicit_albums_2019)
# Out:
# album_name
# HOMECOMING: THE LIVE ALBUM    40
# Name: count, dtype: int64

# %%
# Lets extract the 2022 explicit tracks data

explicit_tracks_2022 = df[df['release_date_parsed'].dt.year == 2022]['track_name']

# Print the name of the most explicit 2014 album
explicit_albums_2022 = df[df['release_date_parsed'].dt.year == 2022]['album_name'].value_counts()
print(explicit_albums_2022)
# Out:
# album_name
# RENAISSANCE              16
# BREAK MY SOUL REMIXES     4
# Name: count, dtype: int64

# %%
# Check loudness
# Group by release year and calculate the mean danceability for each year

avg_loudness = df.groupby(df['release_date_parsed'].dt.year)['loudness'].mean()

# Plot the average danceability by release year
ax = avg_loudness.plot(kind='bar', title='Average Loudness by Release Year')
ax.set_xlabel('Release Year')
ax.set_ylabel('Average Loudness')

# Rotate x-axis labels
plt.xticks(rotation=45)

plt.show()

# %%
# Print the loudness of the least loud 2019 track
loudness_tracks_2019 = df[df['release_date_parsed'].dt.year == 2019]['loudness']
print(loudness_tracks_2019.min())

# Identify which specific track had this minimal loudness value
min_loudness_index = loudness_tracks_2019.idxmin()
track_name_min_loudness = df.loc[min_loudness_index, 'track_name']
print("Track with the least loudness in 2019:", track_name_min_loudness)
# Out:
# -27.432
# Track with the least loudness in 2019: So Much Damn Swag - Interlude - Homecoming Live

# %%
# Check energy
# Group by release year and calculate the mean energy for each year

avg_energy = df.groupby(df['release_date_parsed'].dt.year)['energy'].mean()

# Plot the average danceability by release year
ax = avg_energy.plot(kind='bar', title='Average energy by Release Year')
ax.set_xlabel('Release Year')
ax.set_ylabel('Average Energy')

# Rotate x-axis labels
plt.xticks(rotation=45)

plt.show()

# %%
# Compare two features side by side on a scatter plot
df.plot(kind='scatter', x='acousticness', y='loudness', title='Accousticness vs Loudness')
plt.show()

# %%
# Create a scatter plot with regression line comparing speechiness and tempo
sns.regplot(data=df, x='loudness', y='tempo')
plt.title('Loudness vs Tempo')
plt.show()

# %%
# Create a scatter plot with regression line comparing speechiness and tempo
sns.regplot(data=df, x='speechiness', y='tempo')
plt.title('Speechiness vs Tempo')
plt.show()

# %%
# Select columns for correlation
selected_columns = ['release_date_parsed', 'valence', 'acousticness', 'duration_ms', 'speechiness', 'energy', 'danceability', 'tempo', 'is_explicit']

# Calculate correlation matrix
df_corr = df[selected_columns].dropna().corr()

# Visualize correlation matrix using a heatmap
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
# A moderate positive correlation implies that tracks with higher valence tend to be more danceable 
# This makes sense as happier or more positive songs might be more danceable.

# A moderate positive correlation suggests that there's a trend towards more explicit content being released over time.
# This might reflect changes in cultural norms or the music industry.

# A strong negative correlation indicates that as the energy of a track increases, its acousticness tends to decrease. 
# This suggests that high-energy songs are less likely to be acoustic, which aligns with expectations , 
# as acoustic songs typically have a softer, more subdued sound compared to high-energy tracks.

# A very weak negative correlation implies that there's no significant relationship between danceability and release date. 
# This suggests that danceability hasn't changed much over time.

# Another very weak negative correlation suggests that there's a slight tendency for tracks with higher tempo to have lower danceability.
# This could mean that faster songs might not always be as danceable.

# A very weak negative correlation suggests that there's no significant relationship between danceability and explicitness.
# This implies that the explicitness of a song doesn't affect its danceability.
